# %% [markdown]
# ## For this project, I will:
# - define a regression or a classification problem
# - choosing an evaluation metric
# - establishing baseline predictions
# - fitting and evaluating tree-based models
# - visualize feature relationships and models

# %%
import pandas as pd
import numpy as np 

# Set my index as the gameId col  
df = pd.read_csv('https://raw.githubusercontent.com/timrocar/Unit-2-Build/master/high_diamond_ranked_10min.csv',
                 index_col='gameId')

# %% [markdown]
# To begin to work on this project, I will first do some EDA, then wrangle my data.

# %%
print(df.shape)
df.head()
# Out:
# (9879, 39)
#             blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# gameId
# 4519157822         0               28                   2               1
# 4523371949         0               12                   1               0
# 4521474530         0               15                   0               0
# 4524384067         0               43                   1               0
# 4436033771         0               75                   4               0
#
#             blueKills  blueDeaths  blueAssists  blueEliteMonsters  \
# gameId
# 4519157822          9           6           11                  0
# 4523371949          5           5            5                  0
# 4521474530          7          11            4                  1
# 4524384067          4           5            5                  1
# 4436033771          6           6            6                  0
#
#             blueDragons  blueHeralds  ...  redTowersDestroyed  redTotalGold  \
# gameId                                ...
# 4519157822            0            0  ...                   0         16567
# 4523371949            0            0  ...                   1         17620
# 4521474530            1            0  ...                   0         17285
# 4524384067            0            1  ...                   0         16478
# 4436033771            0            0  ...                   0         17404
#
#             redAvgLevel  redTotalExperience  redTotalMinionsKilled  \
# gameId
# 4519157822          6.8               17047                    197
# 4523371949          6.8               17438                    240
# 4521474530          6.8               17254                    203
# 4524384067          7.0               17961                    235
# 4436033771          7.0               18313                    225
#
#             redTotalJungleMinionsKilled  redGoldDiff  redExperienceDiff  \
# gameId
# 4519157822                           55         -643                  8
# 4523371949                           52         2908               1173
# 4521474530                           28         1172               1033
# 4524384067                           47         1321                  7
# 4436033771                           67         1004               -230
#
#             redCSPerMin  redGoldPerMin
# gameId
# 4519157822         19.7         1656.7
# 4523371949         24.0         1762.0
# 4521474530         20.3         1728.5
# 4524384067         23.5         1647.8
# 4436033771         22.5         1740.4
#
# [5 rows x 39 columns]

# %%
#lowercase column headers for ease of typing
df.columns = map(str.lower, df.columns)
df.dtypes
# Out:
# bluewins                          int64
# bluewardsplaced                   int64
# bluewardsdestroyed                int64
# bluefirstblood                    int64
# bluekills                         int64
# bluedeaths                        int64
# blueassists                       int64
# blueelitemonsters                 int64
# bluedragons                       int64
# blueheralds                       int64
# bluetowersdestroyed               int64
# bluetotalgold                     int64
# blueavglevel                    float64
# bluetotalexperience               int64
# bluetotalminionskilled            int64
# bluetotaljungleminionskilled      int64
# bluegolddiff                      int64
# blueexperiencediff                int64
# bluecspermin                    float64
# bluegoldpermin                  float64
# redwardsplaced                    int64
# redwardsdestroyed                 int64
# redfirstblood                     int64
# redkills                          int64
# reddeaths                         int64
# redassists                        int64
# redelitemonsters                  int64
# reddragons                        int64
# redheralds                        int64
# redtowersdestroyed                int64
# redtotalgold                      int64
# redavglevel                     float64
# redtotalexperience                int64
# redtotalminionskilled             int64
# redtotaljungleminionskilled       int64
# redgolddiff                       int64
# redexperiencediff                 int64
# redcspermin                     float64
# redgoldpermin                   float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9879 entries, 4519157822 to 4523772935
# Data columns (total 39 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   bluewins                      9879 non-null   int64
#  1   bluewardsplaced               9879 non-null   int64
#  2   bluewardsdestroyed            9879 non-null   int64
#  3   bluefirstblood                9879 non-null   int64
#  4   bluekills                     9879 non-null   int64
#  5   bluedeaths                    9879 non-null   int64
#  6   blueassists                   9879 non-null   int64
#  7   blueelitemonsters             9879 non-null   int64
#  8   bluedragons                   9879 non-null   int64
#  9   blueheralds                   9879 non-null   int64
#  10  bluetowersdestroyed           9879 non-null   int64
#  11  bluetotalgold                 9879 non-null   int64
#  12  blueavglevel                  9879 non-null   float64
#  13  bluetotalexperience           9879 non-null   int64
#  14  bluetotalminionskilled        9879 non-null   int64
#  15  bluetotaljungleminionskilled  9879 non-null   int64
#  16  bluegolddiff                  9879 non-null   int64
#  17  blueexperiencediff            9879 non-null   int64
#  18  bluecspermin                  9879 non-null   float64
#  19  bluegoldpermin                9879 non-null   float64
#  20  redwardsplaced                9879 non-null   int64
#  21  redwardsdestroyed             9879 non-null   int64
#  22  redfirstblood                 9879 non-null   int64
#  23  redkills                      9879 non-null   int64
#  24  reddeaths                     9879 non-null   int64
#  25  redassists                    9879 non-null   int64
#  26  redelitemonsters              9879 non-null   int64
#  27  reddragons                    9879 non-null   int64
#  28  redheralds                    9879 non-null   int64
#  29  redtowersdestroyed            9879 non-null   int64
#  30  redtotalgold                  9879 non-null   int64
#  31  redavglevel                   9879 non-null   float64
#  32  redtotalexperience            9879 non-null   int64
#  33  redtotalminionskilled         9879 non-null   int64
#  34  redtotaljungleminionskilled   9879 non-null   int64
#  35  redgolddiff                   9879 non-null   int64
#  36  redexperiencediff             9879 non-null   int64
#  37  redcspermin                   9879 non-null   float64
#  38  redgoldpermin                 9879 non-null   float64
# dtypes: float64(6), int64(33)
# memory usage: 3.0 MB

# %% [markdown]
# I have no null values, great to see!

# %%
pip install -U pandas-profiling
# Out:
# Requirement already up-to-date: pandas-profiling in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (2.8.0)
# Requirement already satisfied, skipping upgrade: ipywidgets>=7.5.1 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from pandas-profiling) (7.5.1)
# Requirement already satisfied, skipping upgrade: astropy>=4.0 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from pandas-profiling) (4.0.1.post1)
# Requirement already satisfied, skipping upgrade: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from pandas-profiling) (1.1.0)
# Requirement already satisfied, skipping upgrade: tangled-up-in-unicode>=0.0.6 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from pandas-profiling) (0.0.6)
# Requirement already satisfied, skipping upgrade: htmlmin>=0.1.12 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied, skipping upgrade: jinja2>=2.11.1 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from pandas-profiling) (2.11.2)
# Requirement already satisfied, skipping upgrade: requests>=2.23.0 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from pandas-profiling) (2.24.0)
# Requirement already satisfied, skipping upgrade: tqdm>=4.43.0 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from pandas-profiling) (4.48.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.16.0 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from pandas-profiling) (1.19.1)
# Requirement already satisfied, skipping upgrade: visions[type_image_path]==0.4.4 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from pandas-profiling) (0.4.4)
# Requirement already satisfied, skipping upgrade: joblib in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from pandas-profiling) (0.16.0)
# Requirement already satisfied, skipping upgrade: matplotlib>=3.2.0 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from pandas-profiling) (3.3.0)
# Requirement already satisfied, skipping upgrade: missingno>=0.4.2 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from pandas-profiling) (0.4.2)
# Requirement already satisfied, skipping upgrade: scipy>=1.4.1 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from pandas-profiling) (1.5.2)
# Requirement already satisfied, skipping upgrade: confuse>=1.0.0 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from pandas-profiling) (1.3.0)
# Requirement already satisfied, skipping upgrade: phik>=0.9.10 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from pandas-profiling) (0.10.0)
# Requirement already satisfied, skipping upgrade: ipython>=4.0.0; python_version >= "3.3" in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (7.17.0)
# Requirement already satisfied, skipping upgrade: nbformat>=4.2.0 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (5.0.7)
# Requirement already satisfied, skipping upgrade: widgetsnbextension~=3.5.0 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (3.5.1)
# Requirement already satisfied, skipping upgrade: ipykernel>=4.5.1 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (5.3.4)
# Requirement already satisfied, skipping upgrade: traitlets>=4.3.1 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (4.3.3)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->pandas-profiling) (2020.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->pandas-profiling) (2.8.1)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from jinja2>=2.11.1->pandas-profiling) (1.1.1)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from requests>=2.23.0->pandas-profiling) (1.25.10)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from requests>=2.23.0->pandas-profiling) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from requests>=2.23.0->pandas-profiling) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from requests>=2.23.0->pandas-profiling) (2020.6.20)
# Requirement already satisfied, skipping upgrade: attrs>=19.3.0 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from visions[type_image_path]==0.4.4->pandas-profiling) (19.3.0)
# Requirement already satisfied, skipping upgrade: networkx>=2.4 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from visions[type_image_path]==0.4.4->pandas-profiling) (2.5)
# Requirement already satisfied, skipping upgrade: imagehash; extra == "type_image_path" in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from visions[type_image_path]==0.4.4->pandas-profiling) (4.1.0)
# Requirement already satisfied, skipping upgrade: Pillow; extra == "type_image_path" in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from visions[type_image_path]==0.4.4->pandas-profiling) (7.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.2.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.4.7)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.10.0)
# Requirement already satisfied, skipping upgrade: seaborn in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from missingno>=0.4.2->pandas-profiling) (0.10.1)
# Requirement already satisfied, skipping upgrade: pyyaml in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from confuse>=1.0.0->pandas-profiling) (5.3.1)
# Requirement already satisfied, skipping upgrade: numba>=0.38.1 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from phik>=0.9.10->pandas-profiling) (0.51.0)
# Requirement already satisfied, skipping upgrade: decorator in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (4.4.2)
# Requirement already satisfied, skipping upgrade: pygments in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (2.6.1)
# Requirement already satisfied, skipping upgrade: setuptools>=18.5 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (49.2.0)
# Requirement already satisfied, skipping upgrade: jedi>=0.10 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.17.2)
# Requirement already satisfied, skipping upgrade: backcall in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.2.0)
# Requirement already satisfied, skipping upgrade: colorama; sys_platform == "win32" in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.4.3)
# Requirement already satisfied, skipping upgrade: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (3.0.5)
# Requirement already satisfied, skipping upgrade: pickleshare in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.7.5)
# Requirement already satisfied, skipping upgrade: jsonschema!=2.5.0,>=2.4 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling) (3.2.0)
# Requirement already satisfied, skipping upgrade: jupyter-core in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling) (4.6.3)
# Requirement already satisfied, skipping upgrade: ipython-genutils in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling) (0.2.0)
# Requirement already satisfied, skipping upgrade: notebook>=4.4.1 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (6.1.1)
# Requirement already satisfied, skipping upgrade: tornado>=4.2 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling) (6.0.4)
# Requirement already satisfied, skipping upgrade: jupyter-client in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling) (6.1.6)
# Requirement already satisfied, skipping upgrade: six in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from traitlets>=4.3.1->ipywidgets>=7.5.1->pandas-profiling) (1.15.0)
# Requirement already satisfied, skipping upgrade: PyWavelets in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from imagehash; extra == "type_image_path"->visions[type_image_path]==0.4.4->pandas-profiling) (1.1.1)
# Requirement already satisfied, skipping upgrade: llvmlite<0.35,>=0.34.0.dev0 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from numba>=0.38.1->phik>=0.9.10->pandas-profiling) (0.34.0)
# Requirement already satisfied, skipping upgrade: parso<0.8.0,>=0.7.0 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.7.1)
# Requirement already satisfied, skipping upgrade: wcwidth in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.2.5)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling) (0.16.0)
# Requirement already satisfied, skipping upgrade: pywin32>=1.0; sys_platform == "win32" in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling) (228)
# Requirement already satisfied, skipping upgrade: Send2Trash in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (1.5.0)
# Requirement already satisfied, skipping upgrade: terminado>=0.8.3 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.8.3)
# Requirement already satisfied, skipping upgrade: argon2-cffi in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (20.1.0)
# Requirement already satisfied, skipping upgrade: pyzmq>=17 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (19.0.2)
# Requirement already satisfied, skipping upgrade: nbconvert in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (5.6.1)
# Requirement already satisfied, skipping upgrade: prometheus-client in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.8.0)
# Requirement already satisfied, skipping upgrade: pywinpty>=0.5; os_name == "nt" in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.5.7)
# Requirement already satisfied, skipping upgrade: cffi>=1.0.0 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (1.14.1)
# Requirement already satisfied, skipping upgrade: entrypoints>=0.2.2 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.3)
# Requirement already satisfied, skipping upgrade: testpath in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.4.4)
# Requirement already satisfied, skipping upgrade: bleach in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (3.1.5)
# Requirement already satisfied, skipping upgrade: pandocfilters>=1.4.1 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (1.4.2)
# Requirement already satisfied, skipping upgrade: mistune<2,>=0.8.1 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.8.4)
# Requirement already satisfied, skipping upgrade: defusedxml in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.6.0)
# Requirement already satisfied, skipping upgrade: pycparser in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (2.20)
# Requirement already satisfied, skipping upgrade: packaging in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (20.4)
# Requirement already satisfied, skipping upgrade: webencodings in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.5.1)

# %%
from pandas_profiling import ProfileReport
#profile = ProfileReport(df, title='Pandas Profiling Report')
#profile.to_notebook_iframe()

# %% [markdown]
# With the help of some previous domain knowledge, I can see there are many repeated columns( many events on one team are inversely correlated to the other)
# I will start by removing some of them(I will largely be removing the red half of these features)

# %%
repeated = ['redfirstblood', 'redkills', 'reddeaths', 'redgolddiff',
            'redexperiencediff', 'redcspermin',
           'blueavglevel', 'bluecspermin', 'redavglevel', 'bluegoldpermin', 'redgoldpermin']
df = df.drop(repeated, axis=1)

# %%
#bluewins will be my target 
df.bluewins.value_counts()
# Out:
# 0    4949
# 1    4930
# Name: bluewins, dtype: int64

# %% [markdown]
# My target vector, "bluewins", is a classification problem.
# - I will use accuracy as my metric
# - I will use a random 80/20 train-validation split, will not exclude any observations. I will also split off a test set.

# %%
# Correlations

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.figure(figsize=(16, 16))
sns.heatmap(df.drop('bluewins', axis=1).corr(), cmap="RdBu_r", annot =True)
plt.show()

# %% [markdown]
# I can drop some of the features with little correlation to my target vector

# %%
#first ill split off some test data
mask = np.random.rand(len(df)) < 0.901
train = df[mask]
test = df[~mask]

# %%
print(test.shape)
test.head()
# Out:
# (998, 28)
#             bluewins  bluewardsplaced  bluewardsdestroyed  bluefirstblood  \
# gameId
# 4523371949         0               12                   1               0
# 4475365709         1               18                   0               0
# 4486384947         1               21                   4               1
# 4519148589         0              105                   5               1
# 4514402510         0               17                   0               1
#
#             bluekills  bluedeaths  blueassists  blueelitemonsters  \
# gameId
# 4523371949          5           5            5                  0
# 4475365709          5           3            6                  1
# 4486384947          5           4           11                  0
# 4519148589          8           6           13                  1
# 4514402510          5           7            7                  1
#
#             bluedragons  blueheralds  ...  redwardsdestroyed  redassists  \
# gameId                                ...
# 4523371949            0            0  ...                  1           2
# 4475365709            1            0  ...                  5           2
# 4486384947            0            0  ...                  3           3
# 4519148589            1            0  ...                  3          11
# 4514402510            1            0  ...                  0           6
#
#             redelitemonsters  reddragons  redheralds  redtowersdestroyed  \
# gameId
# 4523371949                 2           1           1                   1
# 4475365709                 0           0           0                   0
# 4486384947                 2           1           1                   0
# 4519148589                 0           0           0                   0
# 4514402510                 0           0           0                   0
#
#             redtotalgold  redtotalexperience  redtotalminionskilled  \
# gameId
# 4523371949         17620               17438                    240
# 4475365709         15201               18060                    221
# 4486384947         15400               16866                    228
# 4519148589         16154               17849                    223
# 4514402510         17259               19444                    218
#
#             redtotaljungleminionskilled
# gameId
# 4523371949                           52
# 4475365709                           59
# 4486384947                           52
# 4519148589                           40
# 4514402510                           76
#
# [5 rows x 28 columns]

# %%
corr = train[train.columns[1:]].apply(lambda x: x.corr(train['bluewins']))
cols = []
for col in corr.index:
    if (corr[col]>0.2 or corr[col]<-0.2):
        cols.append(col)
        
cols
# Out:
# ['bluefirstblood',
#  'bluekills',
#  'bluedeaths',
#  'blueassists',
#  'blueelitemonsters',
#  'bluedragons',
#  'bluetotalgold',
#  'bluetotalexperience',
#  'bluetotalminionskilled',
#  'bluegolddiff',
#  'blueexperiencediff',
#  'redassists',
#  'redelitemonsters',
#  'reddragons',
#  'redtotalgold',
#  'redtotalexperience',
#  'redtotalminionskilled']

# %%
testcols = cols + ['bluewins']

# %%
test = test[testcols]
df_new = train[cols]
df_new.head()
# Out:
#             bluefirstblood  bluekills  bluedeaths  blueassists  \
# gameId
# 4519157822               1          9           6           11
# 4521474530               0          7          11            4
# 4524384067               0          4           5            5
# 4436033771               0          6           6            6
# 4493010632               1          7           6            7
#
#             blueelitemonsters  bluedragons  bluetotalgold  \
# gameId
# 4519157822                  0            0          17210
# 4521474530                  1            1          16113
# 4524384067                  1            0          15157
# 4436033771                  0            0          16400
# 4493010632                  1            1          16874
#
#             bluetotalexperience  bluetotalminionskilled  bluegolddiff  \
# gameId
# 4519157822                17039                     195           643
# 4521474530                16221                     186         -1172
# 4524384067                17954                     201         -1321
# 4436033771                18543                     210         -1004
# 4493010632                16967                     225          2411
#
#             blueexperiencediff  redassists  redelitemonsters  reddragons  \
# gameId
# 4519157822                  -8           8                 0           0
# 4521474530               -1033          14                 0           0
# 4524384067                  -7          10                 0           0
# 4436033771                 230           7                 1           1
# 4493010632                1563           9                 0           0
#
#             redtotalgold  redtotalexperience  redtotalminionskilled
# gameId
# 4519157822         16567               17047                    197
# 4521474530         17285               17254                    203
# 4524384067         16478               17961                    235
# 4436033771         17404               18313                    225
# 4493010632         14463               15404                    164

# %%
# Train-Test-Split
from sklearn.model_selection import train_test_split
X = df_new
y = train['bluewins']

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state = 7)

# %%
# Baseline Accuracy

print('Baseline Accuracy:', y_train.value_counts(normalize=True).max())
# Out:
# Baseline Accuracy: 0.5007046223224352

# %%
# Quick Model 

from category_encoders import OneHotEncoder, OrdinalEncoder
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

quickmodel = make_pipeline(
    OrdinalEncoder(),
    StandardScaler(),
    DecisionTreeClassifier(random_state=7, max_depth=4)
)

quickmodel.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('ordinalencoder', OrdinalEncoder(cols=[], mapping=[])),
#                 ('standardscaler', StandardScaler()),
#                 ('decisiontreeclassifier',
#                  DecisionTreeClassifier(max_depth=4, random_state=7))])

# %%
print('Training Accuracy:', quickmodel.score(X_train, y_train))
print('Validation Accuracy:', quickmodel.score(X_val, y_val))
# Out:
# Training Accuracy: 0.7240698985343855
# Validation Accuracy: 0.7363380281690141

# %%
quickrfmodel = make_pipeline(
    OrdinalEncoder(),
    StandardScaler(),
    RandomForestClassifier(random_state=7, max_depth=4)
)

quickrfmodel.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('ordinalencoder', OrdinalEncoder(cols=[], mapping=[])),
#                 ('standardscaler', StandardScaler()),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(max_depth=4, random_state=7))])

# %%
print('Training Accuracy:', quickrfmodel.score(X_train, y_train))
print('Validation Accuracy:', quickrfmodel.score(X_val, y_val))
# Out:
# Training Accuracy: 0.7391488162344984
# Validation Accuracy: 0.7369014084507042

# %%
# Testing Boosting Classifiers!

from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

XGB_model = make_pipeline(
    OrdinalEncoder(),
    StandardScaler(),
    XGBClassifier(random_state= 7, n_jobs=16, max_depth=6, learning_rate=0.003)
)

XGB_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('ordinalencoder', OrdinalEncoder(cols=[], mapping=[])),
#                 ('standardscaler', StandardScaler()),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=0.5, booster='gbtree',
#                                colsample_bylevel=1, colsample_bynode=1,
#                                colsample_bytree=1, gamma=0, gpu_id=-1,
#                                importance_type='gain',
#                                interaction_constraints='', learning_rate=0.003,
#                                max_delta_step=0, max_depth=6,
#                                min_child_weight=1, missing=nan,
#                                monotone_constraints='()', n_estimators=100,
#                                n_jobs=16, num_parallel_tree=1, random_state=7,
#                                reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#                                subsample=1, tree_method='exact',
#                                validate_parameters=1, verbosity=None))])

# %%
print('Training Accuracy:', XGB_model.score(X_train, y_train))
print('Validation Accuracy:', XGB_model.score(X_val, y_val))
# Out:
# Training Accuracy: 0.7625422773393461
# Validation Accuracy: 0.7301408450704225

# %%
from sklearn.inspection import permutation_importance

pi = permutation_importance(XGB_model, X_val, y_val, n_jobs=16)

pi.keys()

data = {'importances_mean': np.round(pi['importances_mean'], 6),
       'importances_std': pi['importances_std']}

df_pi = pd.DataFrame(data, index= X_val.columns).sort_values(by='importances_mean', ascending=False)

df_pi
# Out:
#                         importances_mean  importances_std
# bluegolddiff                    0.162930         0.007271
# blueexperiencediff              0.010592         0.003406
# bluedragons                     0.005634         0.002828
# redassists                      0.002028         0.000915
# reddragons                      0.002028         0.000764
# redtotalgold                    0.001239         0.001724
# bluetotalexperience             0.001127         0.001709
# redelitemonsters                0.000676         0.000747
# bluedeaths                      0.000338         0.001495
# bluetotalminionskilled          0.000113         0.000657
# blueelitemonsters              -0.000113         0.000422
# bluefirstblood                 -0.000225         0.000276
# bluekills                      -0.000451         0.000422
# bluetotalgold                  -0.000563         0.001234
# redtotalexperience             -0.000563         0.001008
# blueassists                    -0.001239         0.000422
# redtotalminionskilled          -0.003718         0.001160

# %%
import plotly.express as px

fig = px.bar(df_pi['importances_mean'])
fig.show()
# Out:
# <div>
#
#
#             <div id="981d8b66-a392-4d9c-a8c5-b4dd716ece55" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("981d8b66-a392-4d9c-a8c5-b4dd716ece55")) {
#                     Plotly.newPlot(
#                         '981d8b66-a392-4d9c-a8c5-b4dd716ece55',
#                         [{"alignmentgroup": "True", "hovertemplate": "variable=importances_mean<br>index=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "importances_mean", "marker": {"color": "#636efa"}, "name": "importances_mean", "offsetgroup": "importances_mean", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["bluegolddiff", "blueexperiencediff", "bluedragons", "redassists", "reddragons", "redtotalgold", "bluetotalexperience", "redelitemonsters", "bluedeaths", "bluetotalminionskilled", "blueelitemonsters", "bluefirstblood", "bluekills", "bluetotalgold", "redtotalexperience", "blueassists", "redtotalminionskilled"], "xaxis": "x", "y": [0.16293, 0.010592, 0.005634, 0.002028, 0.002028, 0.001239, 0.001127, 0.000676, 0.000338, 0.000113, -0.000113, -0.000225, -0.000451, -0.000563, -0.000563, -0.001239, -0.003718], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": { ...

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 72
from pdpbox.pdp import pdp_isolate, pdp_plot

feature = 'bluegolddiff'

onef_pdp = pdp_isolate(
    model=XGB_model,
    dataset=X_val,
    model_features=X_val.columns,
    feature=feature
)

pdp_plot(onef_pdp, feature_name=feature)
plt.xlim(-3000,9000)
plt.show()

# %%
feature = 'blueexperiencediff'

exp_pdp = pdp_isolate(
    model=XGB_model,
    dataset=X_val,
    model_features=X_val.columns,
    feature=feature
)

pdp_plot(exp_pdp, feature_name=feature)
plt.xlim(-3000,9000)
plt.show()

# %%
# PDP w Two Features

from pdpbox.pdp import pdp_interact, pdp_interact_plot

features = ['bluegolddiff', 'blueexperiencediff']

interaction_matrix = pdp_interact(
    model=XGB_model,
    dataset=X_val,
    model_features=X_val.columns,
    features=features
)

pdp_interact_plot(interaction_matrix, plot_type='grid', feature_names=features)
plt.show()

# %%
# !pip install shap
# Out:
# Requirement already satisfied: shap in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (0.35.0)
# Requirement already satisfied: numpy in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from shap) (1.19.1)
# Requirement already satisfied: scipy in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from shap) (1.5.2)
# Requirement already satisfied: scikit-learn in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from shap) (0.23.2)
# Requirement already satisfied: tqdm>4.25.0 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from shap) (4.48.2)
# Requirement already satisfied: pandas in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from shap) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from scikit-learn->shap) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from scikit-learn->shap) (0.16.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from pandas->shap) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from pandas->shap) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\timro\.virtualenvs\unit-2-build-y90-p50g\lib\site-packages (from python-dateutil>=2.7.3->pandas->shap) (1.15.0)

# %%
# Shapley Plots 
import shap


XBCL= XGBClassifier(random_state= 7, n_jobs=16, max_depth=6, learning_rate=0.003)
X_fit= XBCL.fit(X_train, y_train)

mybooster = X_fit.get_booster()

# %%
model_bytearray = mybooster.save_raw()[4:]
def myfun(self=None):
    return model_bytearray
mybooster.save_raw = myfun

# %%
encoder = OrdinalEncoder()
X_train_encoded = encoder.fit_transform(X_train, y_train)

# %%
value = X_train_encoded.iloc[[7]]

# %%
## So our model is predicting a win, lets see why. 
explainer = shap.TreeExplainer(mybooster)
shap_values = explainer.shap_values(value)
shap.initjs()
shap.force_plot(
    base_value=explainer.expected_value,
    shap_values=shap_values,
    features=value
)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iR9564VG3TJDWUOUAMTIH'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["model output value"], "baseValue": -0.0010674778604879975, "outValue": 0.22495736181735992, "link": "identity", "featureNames": ["bluefirstblood", "bluekills", "bluedeaths", "blueassists", "blueelitemonsters", "bluedragons", "bluetotalgold", "bluetotalexperience", "bluetotalminionskilled", "bluegolddiff", "blueexperiencediff", "redassists", "redelitemonsters", "reddragons", "redtotalgold", "redtotalexperience", "redtotalminionskilled"], "features": {"0": {"effect": 0.00025225590798072517, "value": 1.0}, "1": {"effect": -0.0006802540156058967, "value": 4.0}, "2": {"effect": 0.019523750990629196, "value": 4.0}, "3": {"effect": -0.000622968771494925, "value": 5.0}, "4": {"effect": 0.005160503089427948, "value": 1.0}, "5": {"effect": -0.04681104049086571, "value": 0.0}, "6": {"effect": 0.014554363675415516, "value": 16938.0}, "7": {"effect": 0.005283913109451532, "value": 18241.0}, "8": {"effect": 0.0020611626096069813, "value": 213.0}, "9": {"effect": 0.2591129541397095, "value": 1881.0}, "10": {"effect": -0.04698435217142105, "value": 635.0}, "11": {"effect": 8.25839233584702e-05, "value": 5.0}, "12": {"effect": 0.002329370006918907, "value": 0.0}, "13": {"effect": 0.004159728065133095, "value": 0.0}, "14": {"effect": 0.007978416047990322, "value": 15057.0}, "15": {"effect": 0.0035017968621104956, "value": 17606.0}, "16": {"effect": -0.002877328312024474, "value": 224.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iR9564VG3TJDWUOUAMTIH')
#   );
# </script>
