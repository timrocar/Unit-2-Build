# %% [markdown]
# ## For this project, I will:
# - define a regression or a classification problem
# - choosing an evaluation metric
# - establishing baseline predictions
# - fitting and evaluating tree-based models
# - visualize feature relationships and models

# %%
import pandas as pd
import numpy as np 

# Set my index as the gameId col  
df = pd.read_csv('https://raw.githubusercontent.com/timrocar/Unit-2-Build/master/high_diamond_ranked_10min.csv',
                 index_col='gameId')

# %% [markdown]
# To begin to work on this project, I will first do some EDA, then wrangle my data.

# %%
print(df.shape)
df.head()
# Out:
# (9879, 39)
#             blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# gameId
# 4519157822         0               28                   2               1
# 4523371949         0               12                   1               0
# 4521474530         0               15                   0               0
# 4524384067         0               43                   1               0
# 4436033771         0               75                   4               0
#
#             blueKills  blueDeaths  blueAssists  blueEliteMonsters  \
# gameId
# 4519157822          9           6           11                  0
# 4523371949          5           5            5                  0
# 4521474530          7          11            4                  1
# 4524384067          4           5            5                  1
# 4436033771          6           6            6                  0
#
#             blueDragons  blueHeralds  ...  redTowersDestroyed  redTotalGold  \
# gameId                                ...
# 4519157822            0            0  ...                   0         16567
# 4523371949            0            0  ...                   1         17620
# 4521474530            1            0  ...                   0         17285
# 4524384067            0            1  ...                   0         16478
# 4436033771            0            0  ...                   0         17404
#
#             redAvgLevel  redTotalExperience  redTotalMinionsKilled  \
# gameId
# 4519157822          6.8               17047                    197
# 4523371949          6.8               17438                    240
# 4521474530          6.8               17254                    203
# 4524384067          7.0               17961                    235
# 4436033771          7.0               18313                    225
#
#             redTotalJungleMinionsKilled  redGoldDiff  redExperienceDiff  \
# gameId
# 4519157822                           55         -643                  8
# 4523371949                           52         2908               1173
# 4521474530                           28         1172               1033
# 4524384067                           47         1321                  7
# 4436033771                           67         1004               -230
#
#             redCSPerMin  redGoldPerMin
# gameId
# 4519157822         19.7         1656.7
# 4523371949         24.0         1762.0
# 4521474530         20.3         1728.5
# 4524384067         23.5         1647.8
# 4436033771         22.5         1740.4
#
# [5 rows x 39 columns]

# %%
#lowercase column headers for ease of typing
df.columns = map(str.lower, df.columns)
df.dtypes
# Out:
# bluewins                          int64
# bluewardsplaced                   int64
# bluewardsdestroyed                int64
# bluefirstblood                    int64
# bluekills                         int64
# bluedeaths                        int64
# blueassists                       int64
# blueelitemonsters                 int64
# bluedragons                       int64
# blueheralds                       int64
# bluetowersdestroyed               int64
# bluetotalgold                     int64
# blueavglevel                    float64
# bluetotalexperience               int64
# bluetotalminionskilled            int64
# bluetotaljungleminionskilled      int64
# bluegolddiff                      int64
# blueexperiencediff                int64
# bluecspermin                    float64
# bluegoldpermin                  float64
# redwardsplaced                    int64
# redwardsdestroyed                 int64
# redfirstblood                     int64
# redkills                          int64
# reddeaths                         int64
# redassists                        int64
# redelitemonsters                  int64
# reddragons                        int64
# redheralds                        int64
# redtowersdestroyed                int64
# redtotalgold                      int64
# redavglevel                     float64
# redtotalexperience                int64
# redtotalminionskilled             int64
# redtotaljungleminionskilled       int64
# redgolddiff                       int64
# redexperiencediff                 int64
# redcspermin                     float64
# redgoldpermin                   float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9879 entries, 4519157822 to 4523772935
# Data columns (total 39 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   bluewins                      9879 non-null   int64
#  1   bluewardsplaced               9879 non-null   int64
#  2   bluewardsdestroyed            9879 non-null   int64
#  3   bluefirstblood                9879 non-null   int64
#  4   bluekills                     9879 non-null   int64
#  5   bluedeaths                    9879 non-null   int64
#  6   blueassists                   9879 non-null   int64
#  7   blueelitemonsters             9879 non-null   int64
#  8   bluedragons                   9879 non-null   int64
#  9   blueheralds                   9879 non-null   int64
#  10  bluetowersdestroyed           9879 non-null   int64
#  11  bluetotalgold                 9879 non-null   int64
#  12  blueavglevel                  9879 non-null   float64
#  13  bluetotalexperience           9879 non-null   int64
#  14  bluetotalminionskilled        9879 non-null   int64
#  15  bluetotaljungleminionskilled  9879 non-null   int64
#  16  bluegolddiff                  9879 non-null   int64
#  17  blueexperiencediff            9879 non-null   int64
#  18  bluecspermin                  9879 non-null   float64
#  19  bluegoldpermin                9879 non-null   float64
#  20  redwardsplaced                9879 non-null   int64
#  21  redwardsdestroyed             9879 non-null   int64
#  22  redfirstblood                 9879 non-null   int64
#  23  redkills                      9879 non-null   int64
#  24  reddeaths                     9879 non-null   int64
#  25  redassists                    9879 non-null   int64
#  26  redelitemonsters              9879 non-null   int64
#  27  reddragons                    9879 non-null   int64
#  28  redheralds                    9879 non-null   int64
#  29  redtowersdestroyed            9879 non-null   int64
#  30  redtotalgold                  9879 non-null   int64
#  31  redavglevel                   9879 non-null   float64
#  32  redtotalexperience            9879 non-null   int64
#  33  redtotalminionskilled         9879 non-null   int64
#  34  redtotaljungleminionskilled   9879 non-null   int64
#  35  redgolddiff                   9879 non-null   int64
#  36  redexperiencediff             9879 non-null   int64
#  37  redcspermin                   9879 non-null   float64
#  38  redgoldpermin                 9879 non-null   float64
# dtypes: float64(6), int64(33)
# memory usage: 3.0 MB

# %% [markdown]
# I have no null values, great to see!

# %%
pip install -U pandas-profiling
# Out:
# Collecting pandas-profiling
#   Using cached pandas_profiling-2.8.0-py2.py3-none-any.whl (259 kB)
# Collecting ipywidgets>=7.5.1
#   Using cached ipywidgets-7.5.1-py2.py3-none-any.whl (121 kB)
# Collecting phik>=0.9.10
#   Using cached phik-0.10.0-py3-none-any.whl (599 kB)
# Collecting astropy>=4.0
#   Using cached astropy-4.0.1.post1-cp38-cp38-win_amd64.whl (6.2 MB)
# Requirement already satisfied, skipping upgrade: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from pandas-profiling) (1.1.1)
# Requirement already satisfied, skipping upgrade: scipy>=1.4.1 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from pandas-profiling) (1.5.2)
# Requirement already satisfied, skipping upgrade: jinja2>=2.11.1 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from pandas-profiling) (2.11.2)
# Requirement already satisfied, skipping upgrade: tqdm>=4.43.0 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from pandas-profiling) (4.48.2)
# Processing c:\users\timro\appdata\local\pip\cache\wheels\23\14\6e\4be5bfeeb027f4939a01764b48edd5996acf574b0913fe5243\htmlmin-0.1.12-py3-none-any.whl
# Collecting tangled-up-in-unicode>=0.0.6
#   Using cached tangled_up_in_unicode-0.0.6-py3-none-any.whl (3.1 MB)
# Collecting visions[type_image_path]==0.4.4
#   Using cached visions-0.4.4-py3-none-any.whl (59 kB)
# Collecting confuse>=1.0.0
#   Using cached confuse-1.3.0-py2.py3-none-any.whl (64 kB)
# Collecting requests>=2.23.0
#   Downloading requests-2.24.0-py2.py3-none-any.whl (61 kB)
# Requirement already satisfied, skipping upgrade: joblib in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from pandas-profiling) (0.16.0)
# Collecting missingno>=0.4.2
#   Using cached missingno-0.4.2-py3-none-any.whl (9.7 kB)
# Requirement already satisfied, skipping upgrade: numpy>=1.16.0 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from pandas-profiling) (1.19.1)
# Requirement already satisfied, skipping upgrade: matplotlib>=3.2.0 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from pandas-profiling) (3.3.1)
# Collecting widgetsnbextension~=3.5.0
#   Using cached widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2 MB)
# Requirement already satisfied, skipping upgrade: nbformat>=4.2.0 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (5.0.7)
# Requirement already satisfied, skipping upgrade: ipython>=4.0.0; python_version >= "3.3" in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (7.17.0)
# Requirement already satisfied, skipping upgrade: traitlets>=4.3.1 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (4.3.3)
# Requirement already satisfied, skipping upgrade: ipykernel>=4.5.1 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from ipywidgets>=7.5.1->pandas-profiling) (5.3.4)
# Collecting numba>=0.38.1
#   Using cached numba-0.51.0-cp38-cp38-win_amd64.whl (2.2 MB)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->pandas-profiling) (2020.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->pandas-profiling) (2.8.1)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from jinja2>=2.11.1->pandas-profiling) (1.1.1)
# Collecting networkx>=2.4
#   Using cached networkx-2.5-py3-none-any.whl (1.6 MB)
# Requirement already satisfied, skipping upgrade: attrs>=19.3.0 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from visions[type_image_path]==0.4.4->pandas-profiling) (19.3.0)
# Requirement already satisfied, skipping upgrade: Pillow; extra == "type_image_path" in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from visions[type_image_path]==0.4.4->pandas-profiling) (7.2.0)
# Processing c:\users\timro\appdata\local\pip\cache\wheels\cc\57\bb\6f9f52a6d8187b8f806210e3378837aa4dc6219cd64cb99846\imagehash-4.1.0-py2.py3-none-any.whl
# Collecting pyyaml
#   Using cached PyYAML-5.3.1-cp38-cp38-win_amd64.whl (219 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.23.0->pandas-profiling) (2020.6.20)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.10-py2.py3-none-any.whl (127 kB)
# Collecting seaborn
#   Downloading seaborn-0.10.1-py3-none-any.whl (215 kB)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.4.7)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.2.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.10.0)
# Requirement already satisfied, skipping upgrade: notebook>=4.4.1 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (6.1.3)
# Requirement already satisfied, skipping upgrade: ipython-genutils in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling) (0.2.0)
# Requirement already satisfied, skipping upgrade: jupyter-core in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling) (4.6.3)
# Requirement already satisfied, skipping upgrade: jsonschema!=2.5.0,>=2.4 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling) (3.2.0)
# Requirement already satisfied, skipping upgrade: backcall in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.2.0)
# Requirement already satisfied, skipping upgrade: jedi>=0.10 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.17.2)
# Requirement already satisfied, skipping upgrade: pickleshare in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.7.5)
# Requirement already satisfied, skipping upgrade: pygments in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (2.6.1)
# Requirement already satisfied, skipping upgrade: colorama; sys_platform == "win32" in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.4.3)
# Requirement already satisfied, skipping upgrade: setuptools>=18.5 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (47.1.0)
# Requirement already satisfied, skipping upgrade: decorator in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (4.4.2)
# Requirement already satisfied, skipping upgrade: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (3.0.6)
# Requirement already satisfied, skipping upgrade: six in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from traitlets>=4.3.1->ipywidgets>=7.5.1->pandas-profiling) (1.15.0)
# Requirement already satisfied, skipping upgrade: tornado>=4.2 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling) (6.0.4)
# Requirement already satisfied, skipping upgrade: jupyter-client in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->pandas-profiling) (6.1.6)
# Collecting llvmlite<0.35,>=0.34.0.dev0
#   Using cached llvmlite-0.34.0-cp38-cp38-win_amd64.whl (15.9 MB)
# Collecting PyWavelets
#   Using cached PyWavelets-1.1.1-cp38-cp38-win_amd64.whl (4.3 MB)
# Requirement already satisfied, skipping upgrade: Send2Trash in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (1.5.0)
# Requirement already satisfied, skipping upgrade: terminado>=0.8.3 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.8.3)
# Requirement already satisfied, skipping upgrade: pyzmq>=17 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (19.0.2)
# Requirement already satisfied, skipping upgrade: prometheus-client in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.8.0)
# Requirement already satisfied, skipping upgrade: nbconvert in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (5.6.1)
# Requirement already satisfied, skipping upgrade: argon2-cffi in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (20.1.0)
# Requirement already satisfied, skipping upgrade: pywin32>=1.0; sys_platform == "win32" in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling) (228)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->pandas-profiling) (0.16.0)
# Requirement already satisfied, skipping upgrade: parso<0.8.0,>=0.7.0 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.7.1)
# Requirement already satisfied, skipping upgrade: wcwidth in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.5.1->pandas-profiling) (0.2.5)
# Requirement already satisfied, skipping upgrade: pywinpty>=0.5; os_name == "nt" in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.5.7)
# Requirement already satisfied, skipping upgrade: testpath in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.4.4)
# Requirement already satisfied, skipping upgrade: bleach in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (3.1.5)
# Requirement already satisfied, skipping upgrade: mistune<2,>=0.8.1 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.8.4)
# Requirement already satisfied, skipping upgrade: pandocfilters>=1.4.1 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (1.4.2)
# Requirement already satisfied, skipping upgrade: defusedxml in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.6.0)
# Requirement already satisfied, skipping upgrade: entrypoints>=0.2.2 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.3)
# Requirement already satisfied, skipping upgrade: cffi>=1.0.0 in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (1.14.2)
# Requirement already satisfied, skipping upgrade: webencodings in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (0.5.1)
# Requirement already satisfied, skipping upgrade: packaging in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (20.4)
# Requirement already satisfied, skipping upgrade: pycparser in c:\users\timro\appdata\local\programs\python\python38\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->pandas-profiling) (2.20)
# Installing collected packages: widgetsnbextension, ipywidgets, llvmlite, numba, phik, astropy, htmlmin, tangled-up-in-unicode, networkx, PyWavelets, imagehash, visions, pyyaml, confuse, idna, chardet, urllib3, requests, seaborn, missingno, pandas-profiling
# Successfully installed PyWavelets-1.1.1 astropy-4.0.1.post1 chardet-3.0.4 confuse-1.3.0 htmlmin-0.1.12 idna-2.10 imagehash-4.1.0 ipywidgets-7.5.1 llvmlite-0.34.0 missingno-0.4.2 networkx-2.5 numba-0.51.0 pandas-profiling-2.8.0 phik-0.10.0 pyyaml-5.3.1 requests-2.24.0 seaborn-0.10.1 tangled-up-in-unicode-0.0.6 urllib3-1.25.10 visions-0.4.4 widgetsnbextension-3.5.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2; however, version 20.2.2 is available.
# You should consider upgrading via the 'c:\users\timro\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
from pandas_profiling import ProfileReport
#profile = ProfileReport(df, title='Pandas Profiling Report')
#profile.to_notebook_iframe()

# %% [markdown]
# With the help of some previous domain knowledge and the pandas profile report, I can see there are many repeated columns( many events on one team are inversely correlated to the other)
# I will start by removing some of them(I will largely be removing the red half of these features)

# %%
repeated = ['redfirstblood', 'redkills', 'reddeaths', 'redgolddiff','redfirstblood',
            'redexperiencediff', 'redcspermin', 'redgoldpermin', 'redheralds',
            'blueavglevel', 'bluecspermin', 'bluegoldpermin']
df = df.drop(repeated, axis=1)

# %%
#bluewins will be my target 
df.bluewins.value_counts()
# Out:
# 0    4949
# 1    4930
# Name: bluewins, dtype: int64

# %% [markdown]
# My target vector, "bluewins", is a classification problem.
# - I will use accuracy as my metric
# - I will use a random 80/20 train-validation split, will not exclude any observations. I will also split off a test set.

# %%
# Correlations

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.figure(figsize=(16, 16))
sns.heatmap(df.drop('bluewins', axis=1).corr(), cmap="RdBu_r", annot =True)
plt.show()

# %% [markdown]
# I can drop some of the features with little correlation to my target vector

# %%
#first ill split off some test data
from sklearn.model_selection import train_test_split
train , test = train_test_split (df, test_size = .09, random_state=7)

# %%
print(test.shape)
test.head()
# Out:
# (890, 28)
#             bluewins  bluewardsplaced  bluewardsdestroyed  bluefirstblood  \
# gameId
# 4467514491         1               20                   2               1
# 4478080352         0               16                   1               0
# 4475735084         1               21                   6               0
# 4525786511         1               18                   4               0
# 4517499041         0               12                   3               1
#
#             bluekills  bluedeaths  blueassists  blueelitemonsters  \
# gameId
# 4467514491          9           7           14                  1
# 4478080352          0           8            0                  0
# 4475735084          7           4           11                  0
# 4525786511          8           2           10                  1
# 4517499041          3           4            4                  1
#
#             bluedragons  blueheralds  ...  redwardsdestroyed  redassists  \
# gameId                                ...
# 4467514491            1            0  ...                  2           8
# 4478080352            0            0  ...                  5          10
# 4475735084            0            0  ...                  7           3
# 4525786511            0            1  ...                  3           2
# 4517499041            1            0  ...                  1           6
#
#             redelitemonsters  reddragons  redtowersdestroyed  redtotalgold  \
# gameId
# 4467514491                 0           0                   0         16050
# 4478080352                 2           1                   0         18252
# 4475735084                 1           1                   0         15417
# 4525786511                 0           0                   0         14895
# 4517499041                 0           0                   0         15802
#
#             redavglevel  redtotalexperience  redtotalminionskilled  \
# gameId
# 4467514491          6.8               16682                    205
# 4478080352          7.2               19305                    273
# 4475735084          6.8               17987                    230
# 4525786511          6.6               17802                    241
# 4517499041          7.2               18570                    247
#
#             redtotaljungleminionskilled
# gameId
# 4467514491                           35
# 4478080352                           44
# 4475735084                           56
# 4525786511                           52
# 4517499041                           52
#
# [5 rows x 28 columns]

# %%
corr = train[train.columns[1:]].apply(lambda x: x.corr(train['bluewins']))
cols = []
for col in corr.index:
    if (corr[col]>0.2 or corr[col]<-0.2):
        cols.append(col)
        
cols
# Out:
# ['bluefirstblood',
#  'bluekills',
#  'bluedeaths',
#  'blueassists',
#  'blueelitemonsters',
#  'bluedragons',
#  'bluetotalgold',
#  'bluetotalexperience',
#  'bluetotalminionskilled',
#  'bluegolddiff',
#  'blueexperiencediff',
#  'redassists',
#  'redelitemonsters',
#  'reddragons',
#  'redtotalgold',
#  'redavglevel',
#  'redtotalexperience',
#  'redtotalminionskilled']

# %%
#need to make sure my test data has the same number of features as my training/validation data. 
testcols = cols + ['bluewins']

# %%
test = test[testcols]
df_new = train[cols]
print(df_new.shape)
df_new.head()
# Out:
# (8989, 18)
#             bluefirstblood  bluekills  bluedeaths  blueassists  \
# gameId
# 4459302014               1         10           5           10
# 4521542969               1          6           4           10
# 4452166670               1          4           1            7
# 4502224154               0          4           3            5
# 4521698665               1          5           3            8
#
#             blueelitemonsters  bluedragons  bluetotalgold  \
# gameId
# 4459302014                  0            0          18588
# 4521542969                  2            1          17086
# 4452166670                  2            1          17320
# 4502224154                  1            0          15804
# 4521698665                  2            1          16321
#
#             bluetotalexperience  bluetotalminionskilled  bluegolddiff  \
# gameId
# 4459302014                18890                     229          2824
# 4521542969                17746                     229          1838
# 4452166670                18965                     264          2850
# 4502224154                18509                     228           606
# 4521698665                18143                     249          1151
#
#             blueexperiencediff  redassists  redelitemonsters  reddragons  \
# gameId
# 4459302014                1346           3                 0           0
# 4521542969                -689           7                 0           0
# 4452166670                1646           0                 0           0
# 4502224154                 820           5                 1           1
# 4521698665                -108           4                 0           0
#
#             redtotalgold  redavglevel  redtotalexperience  \
# gameId
# 4459302014         15764          6.8               17544
# 4521542969         15248          7.2               18435
# 4452166670         14470          6.8               17319
# 4502224154         15198          6.8               17689
# 4521698665         15170          7.0               18251
#
#             redtotalminionskilled
# gameId
# 4459302014                    214
# 4521542969                    231
# 4452166670                    248
# 4502224154                    210
# 4521698665                    218

# %%
# Train-Test-Split for training/validation
X = df_new
y = train['bluewins']

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state = 7)

# %%
# Baseline Accuracy

print('Baseline Accuracy:', y_train.value_counts(normalize=True).max())
# Out:
# Baseline Accuracy: 0.5010429703796412

# %% [markdown]
# ### For my models, I will first create simple version, then I will use hyperparameters and grid/randomized searces to improve on them.

# %%
# Quick Model 

from category_encoders import OneHotEncoder, OrdinalEncoder
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

quickmodel = make_pipeline(
    OrdinalEncoder(),
    StandardScaler(),
    DecisionTreeClassifier(random_state=7, max_depth=4)
)

quickmodel.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-33dabc0b3020> in <module>
#       1 # Quick Model
#       2
# ----> 3 from category_encoders import OneHotEncoder, OrdinalEncoder
#       4 from sklearn.pipeline import make_pipeline
#       5 from sklearn.impute import SimpleImputer
#
# ModuleNotFoundError: No module named 'category_encoders'

# %%
print('Training Accuracy:', quickmodel.score(X_train, y_train))
print('Validation Accuracy:', quickmodel.score(X_val, y_val))

# %%
quickrfmodel = make_pipeline(
    OrdinalEncoder(),
    StandardScaler(),
    RandomForestClassifier(random_state=7, max_depth=4)
)

quickrfmodel.fit(X_train, y_train)

# %%
print('Training Accuracy:', quickrfmodel.score(X_train, y_train))
print('Validation Accuracy:', quickrfmodel.score(X_val, y_val))

# %%
# Testing Boosting Classifiers!

from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

XGB_model = make_pipeline(
    OrdinalEncoder(),
    StandardScaler(),
    XGBClassifier(random_state= 7, n_jobs=16, max_depth=6, learning_rate=0.003)
)

XGB_model.fit(X_train, y_train)

# %%
print('Training Accuracy:', XGB_model.score(X_train, y_train))
print('Validation Accuracy:', XGB_model.score(X_val, y_val))

# %% [markdown]
# ### Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
# I will just use a randomize grid search for my RandomForest Model and my XGBoost Model

params = {'randomforestclassifier__max_leaf_nodes': range(10, 500, 5),
          'randomforestclassifier__n_estimators': range(10,120,5),
          'randomforestclassifier__min_samples_leaf': range(1, 40, 1),
          'randomforestclassifier__min_samples_split': range(1,40, 1)}

tunedrf = RandomizedSearchCV(quickrfmodel,
                          param_distributions=params,
                          n_iter=100,
                          n_jobs=-1,
                          verbose=2)

tunedrf.fit(X_train, y_train)

# %%
print(tunedrf.best_params_)
tunedrf_model = tunedrf.best_estimator_

# %%
print('Random Forest w/o randomized tuning:')
print('Training Accuracy:', quickrfmodel.score(X_train, y_train))
print('Validation Accuracy:', quickrfmodel.score(X_val, y_val))
print('Random Forest w randomized tuning:')
print('Training Accuracy:', tunedrf_model.score(X_train, y_train))
print('Validation Accuracy:', tunedrf_model.score(X_val, y_val))

# %%
# interestingly my metrics didn't improve much with a randomized search, I will attempt a grid search. 
params = {'randomforestclassifier__max_leaf_nodes': range(400, 500, 5),
          'randomforestclassifier__n_estimators': range(30,75,5),
          'randomforestclassifier__min_samples_leaf': range(1, 10, 2),
          'randomforestclassifier__min_samples_split': range(1,20, 2)}

gridtunedrf = GridSearchCV(quickrfmodel,
                          param_grid=params,
                          n_jobs=-1,
                          verbose=2)

gridtunedrf.fit(X_train, y_train)

# %%
print(gridtunedrf.best_params_)
gridtunedrfmodel = tunedrf.best_estimator_

# %%
print('Random Forest w/o grid tuning:')
print('Training Accuracy:', quickrfmodel.score(X_train, y_train))
print('Validation Accuracy:', quickrfmodel.score(X_val, y_val))
print('Random Forest w grid tuning:')
print('Training Accuracy:', gridtunedrfmodel.score(X_train, y_train))
print('Validation Accuracy:', gridtunedrf.score(X_val, y_val))

# %% [markdown]
# I will now work on my XGBoost model

# %%
params = {'xgbclassifier__learning_rate': np.arange(0.01, 0.1, .01),
          'xgbclassifier__subsample': np.arange(0.3, 0.9, 0.1),
          'xgbclassifier__max_depth': range(3, 6, 1),
          'xgbclassifier__colsample_bytree': np.arange(0.5, 0.9, 0.1)
}

tunedxgb = RandomizedSearchCV(XGB_model,
                        param_distributions=params,
                        n_iter=10,
                        scoring = 'roc_auc',      
                        n_jobs=-1,
                        verbose=2)


tunedxgb.fit(X_train, y_train)

# %%
print(tunedxgb.best_params_)
tunedxgbmodel = tunedxgb.best_estimator_

# %%
print('XGBoost w/o randomized tuning:')
print('Training Accuracy:', XGB_model.score(X_train, y_train))
print('Validation Accuracy:', XGB_model.score(X_val, y_val))
print('XGBoost w randomized tuning:')
print('Training Accuracy:', tunedxgbmodel.score(X_train, y_train))
print('Validation Accuracy:', tunedxgbmodel.score(X_val, y_val))

# %%
params = {'xgbclassifier__learning_rate': np.arange(0.01, 0.1, .01),
          'xgbclassifier__subsample': np.arange(0.3, 0.9, 0.1),
          'xgbclassifier__max_depth': range(3, 6, 1),
          'xgbclassifier__colsample_bytree': np.arange(0.5, 0.9, 0.1)
         }
          
gridtunedxgb = GridSearchCV(XGB_model,
                          param_grid=params,
                          n_jobs=-1,
                          scoring = 'roc_auc',
                          verbose=2)

gridtunedxgb.fit(X_train, y_train)

# %%
print(gridtunedxgb.best_params_)
gridtunedxgbmodel = gridtunedxgb.best_estimator_

# %%
print('XGBoost w/o grid tuning:')
print('Training Accuracy:', XGB_model.score(X_train, y_train))
print('Validation Accuracy:', XGB_model.score(X_val, y_val))
print('XGBoost w grid tuning:')
print('Training Accuracy:', gridtunedxgbmodel.score(X_train, y_train))
print('Validation Accuracy:', gridtunedxgbmodel.score(X_val, y_val))

# %% [markdown]
# ### Testing Score

# %%
y_test = test['bluewins'] 
X_test = test[cols]

print('Training Accuracy:', gridtunedxgbmodel.score(X_train, y_train))
print('Testing Accuracy:', gridtunedxgbmodel.score(X_test, y_test))

# %% [markdown]
# The Grid-Tuned XGBoost Model is my best yet, so I will use this for my visualizaitons of feature importances.

# %%
final_model = gridtunedxgbmodel

# %%
from sklearn.metrics import roc_curve, roc_auc_score
#untuned model
y_pred_prob = XGB_model.predict_proba(X_val)[:, -1]
fpr, tpr, thresholds = roc_curve(y_val, y_pred_prob)

# Tuned Model 
tuned_y_pred_prob = final_model.predict_proba(X_val)[:, -1]
fpr_t, tpr_t, thresholds_t = roc_curve(y_val, tuned_y_pred_prob)

# %%
plt.plot(fpr, tpr, label = 'untuned XGBoost')
plt.plot(fpr_t, tpr_t, label = 'Tuned XGBoost', color='red')
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend();

# %%
print('untuned XGBoost ROC-AUC:', roc_auc_score(y_val, y_pred_prob))
print('Tuned XGBoost ROC-AUC:', roc_auc_score(y_val, tuned_y_pred_prob))

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(final_model, X_val, y_val,
                      values_format='.0f',
                      display_labels=['Blue Wins', 'Blue Loses']);

# %%
from sklearn.inspection import permutation_importance

pi = permutation_importance(final_model, X_val, y_val, n_jobs=16)

pi.keys()

data = {'importances_mean': np.round(pi['importances_mean'], 6),
       'importances_std': pi['importances_std']}

df_pi = pd.DataFrame(data, index= X_val.columns).sort_values(by='importances_mean', ascending=False)

df_pi

# %%
import plotly.express as px

fig = px.bar(df_pi['importances_mean'])
fig.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 72
from pdpbox.pdp import pdp_isolate, pdp_plot

feature = 'bluegolddiff'

onef_pdp = pdp_isolate(
    model=final_model,
    dataset=X_val,
    model_features=X_val.columns,
    feature=feature
)

pdp_plot(onef_pdp, feature_name=feature)
plt.xlim(-3000,9000)
plt.show()

# %%
feature = 'blueexperiencediff'

exp_pdp = pdp_isolate(
    model=XGB_model,
    dataset=X_val,
    model_features=X_val.columns,
    feature=feature
)

pdp_plot(exp_pdp, feature_name=feature)
plt.xlim(-3000,9000)
plt.show()

# %%
# PDP w Two Features

from pdpbox.pdp import pdp_interact, pdp_interact_plot

features = ['bluegolddiff', 'blueexperiencediff']

interaction_matrix = pdp_interact(
    model=final_model,
    dataset=X_val,
    model_features=X_val.columns,
    features=features
)

pdp_interact_plot(interaction_matrix, plot_type='grid', feature_names=features)

plt.show()

# %%
# !pip install shap

# %%
final_model

# %%
# Shapley Plots 
import shap


XBCL= XGBClassifier(base_score=0.5, booster='gbtree',
                               colsample_bylevel=1, colsample_bynode=1,
                               colsample_bytree=0.5, gamma=0, gpu_id=-1,
                               importance_type='gain',
                               interaction_constraints='', learning_rate=0.03,
                               max_delta_step=0, max_depth=3,
                               min_child_weight=1,
                                monotone_constraints='()', n_estimators=100,
                               n_jobs=16, num_parallel_tree=1, random_state=7,
                               reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
                               subsample=0.3, tree_method='exact',
                               validate_parameters=1, verbosity=None)

X_fit= XBCL.fit(X_train, y_train)

mybooster = X_fit.get_booster()

# %%
model_bytearray = mybooster.save_raw()[4:]
def myfun(self=None):
    return model_bytearray
mybooster.save_raw = myfun

# %%
encoder = OrdinalEncoder()
X_train_encoded = encoder.fit_transform(X_train, y_train)

# %%
value = X_train_encoded.iloc[[100]]

# %%
value

# %%
## So our model is predicting a win, lets see why. 
explainer = shap.TreeExplainer(mybooster)
shap_values = explainer.shap_values(value)
shap.initjs()
shap.force_plot(
    base_value=explainer.expected_value,
    shap_values=shap_values,
    features=value
)
